# %%
import numpy as np# numpy deals with number and larger size array
import pandas as pd#pandas deals with the discriptive statistics
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\satwik\\Desktop\\Data Sets'

# %%
cd
# Out:
# C:\Users\satwik

# %%
cd Desktop/
# Out:
# C:\Users\satwik\Desktop

# %%
cd Data Sets
# Out:
# C:\Users\satwik\Desktop\Data Sets

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is DA76-C8A2
#
#  Directory of C:\Users\satwik\Desktop\Data Sets
#
# 30-05-2018  10:51    <DIR>          .
# 30-05-2018  10:51    <DIR>          ..
# 22-05-2018  11:35             2,438 50_startups.csv
# 17-05-2018  23:44             9,739 assign1.xlsx
# 23-05-2018  09:26           554,144 bikebuyer1.csv
# 30-05-2018  21:21           616,875 bikebuyerne.csv
# 30-05-2018  10:51           616,875 bikebuyernew.csv
# 21-05-2018  11:45               388 challenger.csv
# 29-05-2018  10:52    <DIR>          data
# 23-05-2018  11:03           125,773 data (1).csv
# 24-05-2018  12:09             2,798 data_collected.csv
# 22-05-2018  09:29            54,288 insurance.csv
# 25-05-2018  12:15             5,107 Iris.csv
# 20-05-2018  20:57                57 New Text Document.txt
# 18-05-2018  11:34               693 sales.csv
# 20-05-2018  21:27                39 sdb.txt
# 20-05-2018  21:47                56 sdb-1.txt
# ...

# %%
data1=pd.read_csv('bikebuyer1.csv')

# %%
data1.head()#5 upper entries of dataset
# Out:
#         ID Marital Status  Gender  Yearly Income  Children        Education  \
# 0  22711.0         Single    Male          30000       0.0  Partial College
# 1  13555.0        Married  Female          40000       0.0  Graduate Degree
# 2      NaN        Married    Male         160000       5.0  Partial College
# 3      2.0         Single    Male         160000       0.0  Graduate Degree
# 4  25410.0            NaN  Female          70000       2.0        Bachelors
#
#        Occupation Home Owner  Cars  Commute Distance         Region  Age  \
# 0        Clerical         No     1               1.0         Europe   33
# 1        Clerical        Yes     0               1.0         Europe   37
# 2    Professional         No     3               2.0         Europe   55
# 3      Management        Yes     2               5.0        Pacific   47
# 4  Skilled Manual         No     1               1.0  North America   38
#
#   Bike Buyer
# 0        Yes
# 1        Yes
# 2         No
# ...

# %%
data1.tail()#5 last entries of datset
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 6992  22820.0        Married    Male         100000       4.0
# 6993  22821.0        Married  Female         130000       4.0
# 6994  22823.0        Married  Female         160000       5.0
# 6995  22825.0         Single  Female         120000       5.0
# 6996  22826.0        Married    Male         130000       5.0
#
#             Education    Occupation Home Owner  Cars  Commute Distance  \
# 6992      High School  Professional        Yes     3               1.0
# 6993  Partial College  Professional        Yes     4               2.0
# 6994        Bachelors    Management        Yes     2               1.0
# 6995  Partial College  Professional        Yes     3               1.0
# 6996      High School  Professional        Yes     3               2.0
#
#       Region  Age Bike Buyer
# 6992  Europe   52         No
# 6993  Europe   52         No
# 6994  Europe   53         No
# 6995  Europe   54         No
# ...

# %%
data1
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 1     13555.0        Married  Female          40000       0.0
# 2         NaN        Married    Male         160000       5.0
# 3         2.0         Single    Male         160000       0.0
# 4     25410.0            NaN  Female          70000       2.0
# 5         4.0        Married     NaN         120000       2.0
# 6     15756.0         Single  Female          70000       0.0
# 7     11085.0         Single  Female          60000       0.0
# 8     17974.0            NaN  Female              0       NaN
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single     NaN          60000       0.0
# 13    14902.0            NaN  Female          40000       0.0
# ...

# %%
data1.corr()#yearly incoms,car,age is the significant factors which is affecting the dataset
# Out:
#                         ID  Yearly Income  Children      Cars  \
# ID                1.000000      -0.006802  0.012046  0.068315
# Yearly Income    -0.006802       1.000000  0.474575  0.472089
# Children          0.012046       0.474575  1.000000  0.448379
# Cars              0.068315       0.472089  0.448379  1.000000
# Commute Distance  0.011511       0.009467  0.026377  0.018397
# Age               0.021135       0.195351 -0.000520  0.141093
#
#                   Commute Distance       Age
# ID                        0.011511  0.021135
# Yearly Income             0.009467  0.195351
# Children                  0.026377 -0.000520
# Cars                      0.018397  0.141093
# Commute Distance          1.000000 -0.026119
# Age                      -0.026119  1.000000

# %%
data1.std()#standard deviation of data
# Out:
# ID                   4337.428859
# Yearly Income       32080.449720
# Children                1.600912
# Cars                    1.146782
# Commute Distance        2.926211
# Age                    11.916654
# dtype: float64

# %%
data1.describe()
# Out:
#                  ID  Yearly Income     Children         Cars  \
# count   6996.000000    6997.000000  6979.000000  6997.000000
# mean   17744.435249   57020.151493     1.111621     1.586823
# std     4337.428859   32080.449720     1.600912     1.146782
# min        2.000000       0.000000     0.000000     0.000000
# 25%    14249.750000   30000.000000     0.000000     1.000000
# 50%    17406.500000   60000.000000     0.000000     2.000000
# 75%    20609.500000   70000.000000     2.000000     2.000000
# max    29476.000000  170000.000000     5.000000     4.000000
#
#        Commute Distance          Age
# count       6968.000000  6997.000000
# mean           4.210103    45.107332
# std            2.926211    11.916654
# min            1.000000    25.000000
# 25%            1.000000    36.000000
# 50%            4.000000    44.000000
# 75%            6.000000    53.000000
# max           13.000000    96.000000

# %%
data1.count()
# Out:
# ID                  6996
# Marital Status      6981
# Gender              6968
# Yearly Income       6997
# Children            6979
# Education           6997
# Occupation          6997
# Home Owner          6997
# Cars                6997
# Commute Distance    6968
# Region              6997
# Age                 6997
# Bike Buyer          6997
# dtype: int64

# %%
data1.shape #there are 6997 rows and 12 columns in the dataset
# Out:
# (6997, 13)

# %%
#every dataset is the combination of feature and target or dependent and independent. In our dataset till age there 
# are features and bikebuyer is the target variable

# %%
data1.columns
# Out:
# Index(['ID', 'Marital Status', 'Gender', 'Yearly Income', 'Children',
#        'Education', 'Occupation', 'Home Owner', 'Cars', 'Commute Distance',
#        'Region', 'Age', 'Bike Buyer'],
#       dtype='object')

# %%
data1=data1.iloc[:,1:]
data1
# Out:
#      Marital Status  Gender  Yearly Income  Children            Education  \
# 0            Single    Male          30000       0.0      Partial College
# 1           Married  Female          40000       0.0      Graduate Degree
# 2           Married    Male         160000       5.0      Partial College
# 3            Single    Male         160000       0.0      Graduate Degree
# 4               NaN  Female          70000       2.0            Bachelors
# 5           Married     NaN         120000       2.0            Bachelors
# 6            Single  Female          70000       0.0          High School
# 7            Single  Female          60000       0.0          High School
# 8               NaN  Female              0       NaN            Bachelors
# 9            Single  Female          20000       1.0      Partial College
# 10           Single    Male          50000       0.0            Bachelors
# 11          Married  Female          70000       2.0      Partial College
# ...

# %%
data1['Yearly Income'].min()
# Out:
# 0

# %%
data1['Yearly Income'].max()
# Out:
# 170000

# %% [markdown]
# # data visualization

# %%
#histogram plot is used to explor one variable

# %%
data1['Yearly Income'].hist() #among approax seven thousand people ,approax 1500 people's yearly income is in approax 
#twenty thousand to thirty thousand. this graph is trying to explain the for limited range of income there are limited
#there are limited peoples so this is the distribution of yerly income.it is the list of people which satisfying this 
#criteria

# %%
#box plot is used to find the outliers we can calculate outliers by a formula 
#1.5(interquartile range)
#thera are two type of outliers one is lower outliers and other is outer outliers

# %%
data1.boxplot(column='Yearly Income')#the green line in the middle of boxplot tells us the median
# here median =62500(APPROAX)
#it also talks about outliers 
#yearly income of range 150000,162500,175000 are the outliers bcz it is just disturbing the dataset
#it also decreasing the accuracy of model

# %%
median= data1.loc[data1["Yearly Income"]<135000,'Yearly Income'].median()

# %%
data1.loc[data1['Yearly Income'] >135000,'Yearly Income']=np.nan

# %%
data1['Yearly Income'].fillna(median ,inplace=True)

# %%
data1['Yearly Income'].max()
# Out:
# 130000.0

# %%
data1=data1[np.abs(data1['Yearly Income']-data1['Yearly Income'].mean())<=(3*data1['Yearly Income'].std())]
data1.boxplot(column='Yearly Income')
print(data1.shape)
# Out:
# (6997, 12)

# %%
data1['Children'].max()
# Out:
# 5.0

# %%
data1['Children'].hist(bins=10)#bins is basically to define the range or we also call it as a bucket 0 to 1
# means it contain 10 quantities
#this children histogram explaining the distribution of child in data 
#like how many children person have 
#approax 0-1 there are more than four thousand peoples have 
#1-2 approax 900 people hava
#so this box plot is explaing such a distribution of child among children

# %%
data1.boxplot(column='Children')#this box plot has no outliers median of 0 we can calculate outliers by this formula
#1.5(IQR)

# %%
data1['Cars'].min()
# Out:
# 0

# %%
data1["Cars"].max()
# Out:
# 4

# %%
data1['Cars'].hist(bins=10)#almost more than 2500 people have more than 2 cars in this dataset

# %%
data1.boxplot(column='Cars')#those have 4 cars are the outliers in the dataset creating the disturbance in the dataset 
#median=2

# %%
median= data1.loc[data1['Cars'] <3,'Cars'].median()

# %%
median
# Out:
# 1.0

# %%
data1.loc[data1['Cars'] >3,'Cars']=np.nan

# %%
data1
# Out:
#      Marital Status  Gender  Yearly Income  Children            Education  \
# 0            Single    Male        30000.0       0.0      Partial College
# 1           Married  Female        40000.0       0.0      Graduate Degree
# 2           Married    Male        60000.0       5.0      Partial College
# 3            Single    Male        60000.0       0.0      Graduate Degree
# 4               NaN  Female        70000.0       2.0            Bachelors
# 5           Married     NaN       120000.0       2.0            Bachelors
# 6            Single  Female        70000.0       0.0          High School
# 7            Single  Female        60000.0       0.0          High School
# 8               NaN  Female            0.0       NaN            Bachelors
# 9            Single  Female        20000.0       1.0      Partial College
# 10           Single    Male        50000.0       0.0            Bachelors
# 11          Married  Female        70000.0       2.0      Partial College
# ...

# %%
data1['Cars'].fillna( value = median,inplace=True)

# %%
data1["Cars"].max
# Out:
# <bound method Series.max of 0       1.0
# 1       0.0
# 2       3.0
# 3       2.0
# 4       1.0
# 5       3.0
# 6       2.0
# 7       2.0
# 8       0.0
# 9       0.0
# 10      2.0
# 11      0.0
# 12      2.0
# 13      1.0
# 14      1.0
# 15      1.0
# 16      1.0
# 17      1.0
# 18      1.0
# 19      1.0
# 20      2.0
# 21      1.0
# 22      2.0
# 23      0.0
# 24      2.0
# 25      2.0
# 26      2.0
# 27      2.0
# 28      1.0
# 29      0.0
#        ...
# 6967    2.0
# 6968    1.0
# 6969    2.0
# 6970    3.0
# 6971    1.0
# 6972    1.0
# 6973    1.0
# 6974    3.0
# 6975    3.0
# 6976    1.0
# 6977    1.0
# 6978    1.0
# 6979    1.0
# 6980    2.0
# 6981    2.0
# 6982    2.0
# 6983    1.0
# 6984    2.0
# 6985    1.0
# 6986    1.0
# 6987    1.0
# 6988    1.0
# 6989    1.0
# 6990    1.0
# 6991    2.0
# 6992    3.0
# 6993    1.0
# 6994    2.0
# 6995    3.0
# 6996    3.0
# Name: Cars, Length: 6997, dtype: float64>

# %%
data1["Commute Distance"].max()#13 time maxximum can go here and there or making any ride
# Out:
# 13.0

# %%
data1['Commute Distance'].min()#1 time minimum ride
# Out:
# 1.0

# %%
data1['Commute Distance'].hist(bins=10)#approax more 2800 people's commute distance is atleat one or two time
#this the range of people 
#only few people making commute distance 13 times in dataset

# %%
data1.boxplot(column='Commute Distance')#the middle green line tells us that median of column dataset 
#

# %%
data1["Age"].max()
# Out:
# 96

# %%
data1["Age"].min()
# Out:
# 25

# %%
data1['Age'].hist(bins=10)#this histogram plot is showing that 40-45 years people are approax 1600 in number in out datset

# %%
data1.boxplot(column='Age')#upper outlier=77.5 approax so above this all are the outliers and creating disturbance in 
# dataset
#meadian=45
#lower outlier<30 are the lower outliers 
#outliers are basically which are not properly fitting in our dataset

# %%
median=data1.loc[data1['Age']<78,'Age'].median()

# %%
median
# Out:
# 43.0

# %%
import numpy as np

# %%
data1.loc[data1['Age']>78,'Age']=np.nan

# %%
data1['Age'].fillna(value=median,inplace=True)

# %%
data1["Age"]
# Out:
# 0       33.0
# 1       37.0
# 2       55.0
# 3       47.0
# 4       38.0
# 5       40.0
# 6       49.0
# 7       49.0
# 8       38.0
# 9       46.0
# 10      64.0
# 11      49.0
# 12      31.0
# 13      50.0
# 14      49.0
# 15      44.0
# 16      39.0
# 17      51.0
# 18      48.0
# 19      45.0
# 20      43.0
# 21      41.0
# 22      44.0
# 23      37.0
# 24      44.0
# 25      62.0
# 26      44.0
# 27      44.0
# 28      49.0
# 29      37.0
#         ...
# 6967    54.0
# 6968    55.0
# 6969    54.0
# 6970    54.0
# 6971    53.0
# 6972    53.0
# 6973    48.0
# 6974    49.0
# 6975    49.0
# 6976    49.0
# 6977    50.0
# 6978    51.0
# 6979    51.0
# 6980    51.0
# 6981    62.0
# 6982    62.0
# 6983    62.0
# 6984    61.0
# 6985    61.0
# 6986    61.0
# 6987    61.0
# 6988    60.0
# 6989    60.0
# 6990    60.0
# 6991    53.0
# 6992    52.0
# 6993    52.0
# 6994    53.0
# 6995    54.0
# 6996    54.0
# Name: Age, Length: 6997, dtype: float64

# %%
data1.boxplot(column="Age")#when outliers is replaced by median

# %%
data1['Marital Status'].value_counts()
# Out:
# Married    4133
# Single     2848
# Name: Marital Status, dtype: int64

# %%
data1['Gender'].value_counts()
# Out:
# Male      3527
# Female    3441
# Name: Gender, dtype: int64

# %%
data1['Education'].value_counts()
# Out:
# Partial College        1932
# Bachelors              1870
# High School            1313
# Graduate Degree        1272
# Partial High School     610
# Name: Education, dtype: int64

# %%
data1['Occupation'].value_counts()
# Out:
# Professional      2031
# Skilled Manual    1748
# Management        1265
# Manual             990
# Clerical           963
# Name: Occupation, dtype: int64

# %%
data1['Home Owner'].value_counts()
# Out:
# Yes    4979
# No     2018
# Name: Home Owner, dtype: int64

# %%
data1['Region'].value_counts()
# Out:
# North America    3728
# Europe           2096
# Pacific          1173
# Name: Region, dtype: int64

# %%
data1.describe()
# Out:
#        Yearly Income     Children         Cars  Commute Distance         Age
# count    6997.000000  6979.000000  6997.000000       6968.000000  6997.00000
# mean    55689.581249     1.111621     1.345863          4.210103    44.91725
# std     29778.095282     1.600912     0.903824          2.926211    11.59705
# min         0.000000     0.000000     0.000000          1.000000    25.00000
# 25%     30000.000000     0.000000     1.000000          1.000000    36.00000
# 50%     60000.000000     0.000000     1.000000          4.000000    43.00000
# 75%     70000.000000     2.000000     2.000000          6.000000    53.00000
# max    130000.000000     5.000000     3.000000         13.000000    78.00000

# %%
data1.corr()
# Out:
#                   Yearly Income  Children      Cars  Commute Distance  \
# Yearly Income          1.000000  0.451281  0.169690          0.008878
# Children               0.451281  1.000000  0.243753          0.026377
# Cars                   0.169690  0.243753  1.000000          0.006356
# Commute Distance       0.008878  0.026377  0.006356          1.000000
# Age                    0.209482  0.009640  0.137914         -0.023096
#
#                        Age
# Yearly Income     0.209482
# Children          0.009640
# Cars              0.137914
# Commute Distance -0.023096
# Age               1.000000

# %%
#examine Yearly income
data1['Yearly Income'].min()
# Out:
# 0.0

# %%
data1['Yearly Income'].max()
# Out:
# 130000.0

# %%
data1['Yearly Income'].mean()
# Out:
# 55689.58124910676

# %%
data1['Yearly Income'].median()
# Out:
# 60000.0

# %%
np.std(data1['Yearly Income'])
# Out:
# 29775.967287050902

# %%
np.var(data1['Yearly Income'])
# Out:
# 886608227.8795254

# %%
#examine gender
data1['Gender'].value_counts()
# Out:
# Male      3527
# Female    3441
# Name: Gender, dtype: int64

# %%
data1['Gender'].count()
# Out:
# 6968

# %%
data1.apply(lambda x: sum(x.isnull()),axis=0)#these are the missing place in dataset
# Out:
# Marital Status      16
# Gender              29
# Yearly Income        0
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
#examine marital status
data1['Marital Status'].value_counts()
# Out:
# Married    4133
# Single     2848
# Name: Marital Status, dtype: int64

# %%
#data imputation 
data1['Marital Status'].fillna('Married' , inplace=True)
data1['Gender'].value_counts()
# Out:
# Male      3527
# Female    3441
# Name: Gender, dtype: int64

# %%
#After imputation
data1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Marital Status       0
# Gender              29
# Yearly Income        0
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data1['Gender'].fillna('Male' , inplace=True)

# %%
data1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Marital Status       0
# Gender               0
# Yearly Income        0
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data1['Children'].mean()
# Out:
# 1.1116205760137556

# %%
data1['Children'].fillna(data1['Children'].mean() , inplace=True)

# %%
data1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Marital Status       0
# Gender               0
# Yearly Income        0
# Children             0
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data1['Commute Distance'].mean()
# Out:
# 4.210103329506315

# %%
data1['Commute Distance'].fillna(data1['Commute Distance'].mean() , inplace=True)

# %%
data1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Marital Status      0
# Gender              0
# Yearly Income       0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Bike Buyer          0
# dtype: int64

# %%
data1
# Out:
#      Marital Status  Gender  Yearly Income  Children            Education  \
# 0            Single    Male        30000.0  0.000000      Partial College
# 1           Married  Female        40000.0  0.000000      Graduate Degree
# 2           Married    Male        60000.0  5.000000      Partial College
# 3            Single    Male        60000.0  0.000000      Graduate Degree
# 4           Married  Female        70000.0  2.000000            Bachelors
# 5           Married    Male       120000.0  2.000000            Bachelors
# 6            Single  Female        70000.0  0.000000          High School
# 7            Single  Female        60000.0  0.000000          High School
# 8           Married  Female            0.0  1.111621            Bachelors
# 9            Single  Female        20000.0  1.000000      Partial College
# 10           Single    Male        50000.0  0.000000            Bachelors
# 11          Married  Female        70000.0  2.000000      Partial College
# ...

# %%
# Person whose is male and yes
data1[data1['Gender'].str.contains('Male') & data1['Bike Buyer'].str.contains('Yes')]
# Out:
#      Marital Status Gender  Yearly Income  Children            Education  \
# 0            Single   Male        30000.0       0.0      Partial College
# 12           Single   Male        60000.0       0.0      Partial College
# 18           Single   Male            0.0       0.0      Partial College
# 29           Single   Male        40000.0       0.0      Graduate Degree
# 31          Married   Male        70000.0       0.0            Bachelors
# 33           Single   Male        30000.0       0.0            Bachelors
# 44          Married   Male        50000.0       0.0      Graduate Degree
# 45          Married   Male        80000.0       0.0      Graduate Degree
# 48           Single   Male        20000.0       1.0  Partial High School
# 50           Single   Male        60000.0       0.0      Graduate Degree
# 54          Married   Male       110000.0       5.0  Partial High School
# 58          Married   Male        40000.0       0.0      Partial College
# ...

# %%
def match_it2(p,q,r,s) : # p is column1 and q its value , r is second column and s its value 
    print(data1[data1[p].str.contains(q) & data1[r].str.contains(s)])

# %%
match_it2('Gender','Male','Bike Buyer','Yes')
# Out:
#      Marital Status Gender  Yearly Income  Children            Education  \
# 0            Single   Male        30000.0       0.0      Partial College
# 12           Single   Male        60000.0       0.0      Partial College
# 18           Single   Male            0.0       0.0      Partial College
# 29           Single   Male        40000.0       0.0      Graduate Degree
# 31          Married   Male        70000.0       0.0            Bachelors
# 33           Single   Male        30000.0       0.0            Bachelors
# 44          Married   Male        50000.0       0.0      Graduate Degree
# 45          Married   Male        80000.0       0.0      Graduate Degree
# 48           Single   Male        20000.0       1.0  Partial High School
# 50           Single   Male        60000.0       0.0      Graduate Degree
# 54          Married   Male       110000.0       5.0  Partial High School
# 58          Married   Male        40000.0       0.0      Partial College
# ...

# %%
def match_it1(p,q) :
    print(data1[data1[p].str.contains(q)])

# %%
match_it1('Gender','Male')
# Out:
#      Marital Status Gender  Yearly Income  Children            Education  \
# 0            Single   Male        30000.0  0.000000      Partial College
# 2           Married   Male        60000.0  5.000000      Partial College
# 3            Single   Male        60000.0  0.000000      Graduate Degree
# 5           Married   Male       120000.0  2.000000            Bachelors
# 10           Single   Male        50000.0  0.000000            Bachelors
# 12           Single   Male        60000.0  0.000000      Partial College
# 14          Married   Male        90000.0  0.000000      Partial College
# 15           Single   Male        70000.0  0.000000      Partial College
# 18           Single   Male            0.0  0.000000      Partial College
# 21           Single   Male        80000.0  5.000000            Bachelors
# 22          Married   Male        70000.0  4.000000            Bachelors
# 26          Married   Male        70000.0  4.000000      Partial College
# ...

# %%
def matchit_counts2(p,q,r,s) :
    print(data1[data1[p].str.contains(q) & data1[r].str.contains(s)].count())

# %%
data1[data1['Gender'].str.contains('Male') & data1['Bike Buyer'].str.contains('Yes')].count()
# Out:
# Marital Status      478
# Gender              478
# Yearly Income       478
# Children            478
# Education           478
# Occupation          478
# Home Owner          478
# Cars                478
# Commute Distance    478
# Region              478
# Age                 478
# Bike Buyer          478
# dtype: int64

# %%
def matchit_counts1(p,q) :
    print(data1[data1[p].str.contains(q)].count())

# %%
matchit_counts2('Gender','Male','Bike Buyer','Yes')
# Out:
# Marital Status      478
# Gender              478
# Yearly Income       478
# Children            478
# Education           478
# Occupation          478
# Home Owner          478
# Cars                478
# Commute Distance    478
# Region              478
# Age                 478
# Bike Buyer          478
# dtype: int64

# %%
matchit_counts1('Gender','Male')
# Out:
# Marital Status      3556
# Gender              3556
# Yearly Income       3556
# Children            3556
# Education           3556
# Occupation          3556
# Home Owner          3556
# Cars                3556
# Commute Distance    3556
# Region              3556
# Age                 3556
# Bike Buyer          3556
# dtype: int64

# %% [markdown]
# # write csv function

# %%
data1.to_csv('C:\\Users\\Satwik\\Desktop\\Data Sets\\bikebuyerne.csv')

# %% [markdown]
# # Encoding

# %%
x=data1.iloc[:,:-1].values
y=data1.iloc[:,-1].values

# %%
x
# Out:
# array([['Single', 'Male', 30000.0, ..., 1.0, 'Europe', 33.0],
#        ['Married', 'Female', 40000.0, ..., 1.0, 'Europe', 37.0],
#        ['Married', 'Male', 60000.0, ..., 2.0, 'Europe', 55.0],
#        ...,
#        ['Married', 'Female', 60000.0, ..., 1.0, 'Europe', 53.0],
#        ['Single', 'Female', 120000.0, ..., 1.0, 'Europe', 54.0],
#        ['Married', 'Male', 130000.0, ..., 2.0, 'Europe', 54.0]],
#       dtype=object)

# %%
y
# Out:
# array(['Yes', 'Yes', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_x=LabelEncoder()
x[:,0]=labelencoder_x.fit_transform(x[:,0])
x[:,1]=labelencoder_x.fit_transform(x[:,1])
x[:,4]=labelencoder_x.fit_transform(x[:,4])
x[:,5]=labelencoder_x.fit_transform(x[:,5])
x[:,6]=labelencoder_x.fit_transform(x[:,6])
x[:,9]=labelencoder_x.fit_transform(x[:,9])

# %%
x
# Out:
# array([[1, 1, 30000.0, ..., 1.0, 0, 33.0],
#        [0, 0, 40000.0, ..., 1.0, 0, 37.0],
#        [0, 1, 60000.0, ..., 2.0, 0, 55.0],
#        ...,
#        [0, 0, 60000.0, ..., 1.0, 0, 53.0],
#        [1, 0, 120000.0, ..., 1.0, 0, 54.0],
#        [0, 1, 130000.0, ..., 2.0, 0, 54.0]], dtype=object)

# %%
onehotencoder=OneHotEncoder(categorical_features=[4,5,9])
x=onehotencoder.fit_transform(x).toarray()

# %%
x
# Out:
# array([[ 0.,  0.,  0., ...,  1.,  1., 33.],
#        [ 0.,  1.,  0., ...,  0.,  1., 37.],
#        [ 0.,  0.,  0., ...,  3.,  2., 55.],
#        ...,
#        [ 1.,  0.,  0., ...,  2.,  1., 53.],
#        [ 0.,  0.,  0., ...,  3.,  1., 54.],
#        [ 0.,  0.,  1., ...,  3.,  2., 54.]])

# %%
#Normalization
from sklearn import preprocessing
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
minmax.fit(x).transform(x)
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.33333333, 0.        ,
#         0.1509434 ],
#        [0.        , 1.        , 0.        , ..., 0.        , 0.        ,
#         0.22641509],
#        [0.        , 0.        , 0.        , ..., 1.        , 0.08333333,
#         0.56603774],
#        ...,
#        [1.        , 0.        , 0.        , ..., 0.66666667, 0.        ,
#         0.52830189],
#        [0.        , 0.        , 0.        , ..., 1.        , 0.        ,
#         0.54716981],
#        [0.        , 0.        , 1.        , ..., 1.        , 0.08333333,
#         0.54716981]])

# %%
#splitting the data
from sklearn import cross_validation, neighbors
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %% [markdown]
# # Multiple Linear Regression

# %%
X = data1[['Marital Status','Gender','Yearly Income','Children','Education','Occupation','Home Owner','Cars','Commute Distance','Region','Age']]
X=X.values
X[:,0]=labelencoder_x.fit_transform(X[:,0])
X[:,1]=labelencoder_x.fit_transform(X[:,1])
X[:,4]=labelencoder_x.fit_transform(X[:,4])
X[:,5]=labelencoder_x.fit_transform(X[:,5])
X[:,6]=labelencoder_x.fit_transform(X[:,6])
X[:,9]=labelencoder_x.fit_transform(X[:,9])
Y = data1['Bike Buyer']
Y=labelencoder_x.fit_transform(Y)
X=pd.DataFrame(X)
Y=pd.DataFrame(Y)

# %%
import statsmodels.formula.api as sm
model = sm.OLS(Y,X.astype(float)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      0   R-squared:                       0.159
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     119.8
# Date:                Wed, 30 May 2018   Prob (F-statistic):          3.32e-252
# Time:                        21:36:44   Log-Likelihood:                -2517.6
# No. Observations:                6997   AIC:                             5057.
# Df Residuals:                    6986   BIC:                             5133.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.0839      0.008     10.064      0.000       0.068       0.100
# ...

# %%
X = data1[['Marital Status','Yearly Income','Children','Home Owner','Cars','Region','Age']]
X=X.values
X[:,0]=labelencoder_x.fit_transform(X[:,0])
#X[:,1]=labelencoder_x.fit_transform(X[:,1])
X[:,3]=labelencoder_x.fit_transform(X[:,3])
X[:,5]=labelencoder_x.fit_transform(X[:,5])
#X[:,6]=labelencoder_x.fit_transform(X[:,6])
#X[:,9]=labelencoder_x.fit_transform(X[:,9])
Y = data1['Bike Buyer']
Y=labelencoder_x.fit_transform(Y)
X=pd.DataFrame(X)
Y=pd.DataFrame(Y)

# %%
model = sm.OLS(Y,X.astype(float)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      0   R-squared:                       0.158
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     187.3
# Date:                Wed, 30 May 2018   Prob (F-statistic):          2.55e-255
# Time:                        21:38:49   Log-Likelihood:                -2520.6
# No. Observations:                6997   AIC:                             5055.
# Df Residuals:                    6990   BIC:                             5103.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.0888      0.008     11.096      0.000       0.073       0.104
# ...

# %%
plt.plot(X[6],Y,'.')
plt.xlabel('Age')
plt.ylabel('Bike Buyer')
a=Y.mean()
plt.axhline(float(a),color='r',linestyle='-')
plt.show()

# %%
plt.plot(X[1],Y,'.')
plt.xlabel('Age')
plt.ylabel('Bike Buyer')
a=Y.mean()
plt.axhline(float(a),color='r',linestyle='-')
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model.logistic import LogisticRegression
cls = LogisticRegression(random_state = 0)
lr_cls = cls.fit(x_train,y_train)

# %%
lr_y_test = lr_cls.predict(x_test)
lr_y_test
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
lr_y_train = lr_cls.predict(x_train)
lr_y_train
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
clf_cm_test = confusion_matrix(y_test,lr_y_test)
clf_cm_test
# Out:
# array([[1212,    0],
#        [ 188,    0]], dtype=int64)

# %%
accuracy = cls.score(x_test,lr_y_test)

# %%
print(accuracy)
# Out:
# 1.0

# %% [markdown]
# # KNN classification

# %%
#Fitting Classifier to the training set
clf = neighbors.KNeighborsClassifier()
clf.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
#Predicting the Test Set results
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
y_test
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
#build the confusion matrix
from sklearn.metrics import confusion_matrix
clf_cm_test = confusion_matrix(y_test,y_pred)
clf_cm_test
# Out:
# array([[1171,   41],
#        [ 156,   32]], dtype=int64)

# %%
#obtain accuracy
accuracy = clf.score(x_test,y_test)
accuracy
# Out:
# 0.8592857142857143

# %% [markdown]
# # Support Vector Classification

# %%
# support vector classification
from sklearn.svm import SVC
sc = SVC(kernel='rbf')
sc_classifier = sc.fit(x_train,y_train) #model building

# %%
#Predictong on test and train data
svc_y_test = sc_classifier.predict(x_test)
print(svc_y_test)
# Out:
# ['No' 'No' 'No' ... 'No' 'No' 'No']

# %%
svc_y_train = sc_classifier.predict(x_train)
print(svc_y_train)
# Out:
# ['No' 'No' 'No' ... 'No' 'Yes' 'No']

# %%
# building confusion matrux on test and train
from sklearn.metrics import confusion_matrix
svc_cm_test = confusion_matrix(y_test,svc_y_test)
svc_cm_test
# Out:
# array([[1200,   12],
#        [ 176,   12]], dtype=int64)

# %%
svc_cm_train = confusion_matrix(y_train,svc_y_train)
svc_cm_train
# Out:
# array([[4769,   16],
#        [ 705,  107]], dtype=int64)

# %%
#accuracy classification score 
from sklearn.metrics import accuracy_score
svc_acc_test = accuracy_score(y_test,svc_y_test)  # for test
svc_acc_test
# Out:
# 0.8657142857142858

# %%
svc_acc_train = accuracy_score(y_train , svc_y_train) #for train
svc_acc_train
# Out:
# 0.8711809898159728

# %% [markdown]
# # Classification Using Decision Trees

# %%
#Decision Tree Classifier 
from sklearn.tree import DecisionTreeClassifier
dtc_clf = DecisionTreeClassifier()
dtc_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# predicting on test and train data
dtc_y_test = dtc_clf.predict(x_test)
dtc_y_test
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
dtc_y_train = dtc_clf.predict(x_train) 
dtc_y_train
# Out:
# array(['No', 'No', 'Yes', ..., 'No', 'Yes', 'No'], dtype=object)

# %%
# buildind the confusion matrix
from sklearn.metrics import confusion_matrix 
dtc_cm_test = confusion_matrix(y_test,dtc_y_test)
dtc_cm_test
# Out:
# array([[1110,  102],
#        [ 121,   67]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
dtc_accu_test = accuracy_score(y_test,dtc_y_test)
dtc_accu_test
# Out:
# 0.8407142857142857

# %% [markdown]
# # Random Forest Classifier

# %%
#Builds Random  Forest Classifier 
from sklearn.ensemble import RandomForestClassifier

# %%
rmf = RandomForestClassifier(max_depth = 3 , random_state = 0)
rf_classi = rmf.fit(x_train,y_train)

# %%
# pedicting on the test and trian data
rf_y_test  =rf_classi.predict(x_test)
rf_y_test
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
rf_y_train = rf_classi.predict(x_train)
rf_y_train
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
# buliding the confudion matrix
from sklearn.metrics import confusion_matrix
rf_cm_test = confusion_matrix(y_test,rf_y_test)
rf_cm_test
# Out:
# array([[1212,    0],
#        [ 188,    0]], dtype=int64)

# %%
rf_cm_train = confusion_matrix(y_train,rf_y_train)
rf_cm_train
# Out:
# array([[4785,    0],
#        [ 812,    0]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
rf_accu_test  = accuracy_score(y_test,rf_y_test)   # test
rf_accu_test
# Out:
# 0.8657142857142858

# %%
rf_accu_train  = accuracy_score(y_train,rf_y_train)   # test
rf_accu_train
# Out:
# 0.8549222797927462

# %%
#Pecision Score on tets and training dataa
from sklearn.metrics import precision_score
rf_precision_test = precision_score(y_test ,rf_y_test , average = 'weighted')
print(rf_precision_test)
rf_precision_train = precision_score(y_train ,rf_y_train , average = 'weighted')
print(rf_precision_train)
# Out:
# 0.7494612244897959
# 0.7308921044860265
# C:\ml\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.metrics import recall_score
rf_recall_test = recall_score(y_test,rf_y_test ,average ='weighted')
print(rf_recall_test)
rf_recall_train = recall_score(y_train,rf_y_train ,average ='weighted')
print(rf_recall_train)
# Out:
# 0.8657142857142858
# 0.8549222797927462

# %% [markdown]
# # ADA Boosting : Adaptive Bosoting

# %%
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier
seed = 7
num_trees = 30
kfold = model_selection.KFold(n_splits = 10,random_state = seed)
model = AdaBoostClassifier(n_estimators=num_trees,random_state = seed)
results = model_selection.cross_val_score(model,x_train,y_train,cv=kfold)

# %%
results
# Out:
# array([0.8375    , 0.83214286, 0.875     , 0.87321429, 0.84642857,
#        0.86964286, 0.87142857, 0.84794275, 0.84615385, 0.85509839])

# %%
results.mean()
# Out:
# 0.85545521339126

# %% [markdown]
# # FPR Model

# %%
# FPR :(False Positive Rate) = # False Positives / # negatives = FP / (FP+TN)
# TPR :(True Positive Rate) = # True positives / # positives = Recall = TP / (TP+FN)
# Precision =# True positives / # predicted positive = TP/(TP+FP)
# Recall = # True positives / # positives = TP / (TP+FN)

# %%
"""Recall and True Positive Rate (TPR) are exactly the same. 
So the difference is in the precision and the false positive rate.

The main difference between these two types of metrics is that precision denominator contains the False positives
while false positive rate denominator contains the true negatives."""
# Out:
# 'Recall and True Positive Rate (TPR) are exactly the same. \nSo the difference is in the precision and the false positive rate.\n\nThe main difference between these two types of metrics is that precision denominator contains the False positives\nwhile false positive rate denominator contains the true negatives.'

# %%
#    While precision measures the probability of a sample classified as positive to actually be positive,
#   the false positive rate measures the ratio of false positives within the negative samples.
